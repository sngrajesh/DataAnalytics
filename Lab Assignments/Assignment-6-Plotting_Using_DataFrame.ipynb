# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# @title{vertical-output:true}
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Sets/alphabet_stock_data.csv')
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1  2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2  2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3  2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4  2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
#
#      Adj Close   Volume
# 0  1105.619995  2343100
# 1  1120.839966  1964900
# 2  1097.880005  2313400
# 3  1186.920044  2664700
# 4  1186.510010  2387300

# %%
# @title{vertical-output:true}
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       127 non-null    object
#  1   Open       127 non-null    float64
#  2   High       127 non-null    float64
#  3   Low        127 non-null    float64
#  4   Close      127 non-null    float64
#  5   Adj Close  127 non-null    float64
#  6   Volume     127 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# 1. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
df['Date']=pd.to_datetime(df['Date'])

# %%
# @title{vertical-output:true}
plt.figure()
# fdf = df[(df['Date'] >= '2020-01-01') & (df['Date'] <= '2020-12-31')]
fdf=df[df["Date"].between("2020-04-06", "2020-09-24")]
plt.plot(fdf['Date'],fdf['Close'])
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-09-24")]
plt.plot(fdf['Date'],fdf['Open'])
plt.plot(fdf['Date'],fdf['Close'])
plt.xlabel('Date')
plt.ylabel('Opening/Closing Price')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.grid(True)
plt.legend(['Open','Close'])
plt.show()

# %% [markdown]
# 3. Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-04-18")]
plt.bar(fdf['Date'],fdf['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-04-18")]
plt.bar(fdf['Date'],fdf['Open'],width=0.4)
plt.bar([x + pd.Timedelta(days=0.4) for x in fdf['Date']],fdf['Close'],width=0.4)
plt.xlabel('Date')
plt.ylabel('Open/Close Price')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(['Open','Close'])
plt.show()

# %% [markdown]
# 5. Write a Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-04-18")]
plt.bar(fdf['Date'],fdf['Open'])
plt.bar(fdf['Date'],fdf['Close'], bottom=fdf['Open'])
plt.xlabel('Date')
plt.ylabel('Open/Close Price')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend(['Open','Close'])
plt.show()

# %% [markdown]
# 6. Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-04-18")]
plt.barh(fdf['Date'],fdf['Open'])
plt.barh(fdf['Date'],fdf['Close'], left=fdf['Open'])
plt.xlabel('Open/Close Price')
plt.ylabel('Date')
plt.title('Alphabet Inc. Stock Price (2020)')
plt.grid(True)
plt.legend(['Open','Close'])
plt.show()

# %% [markdown]
# 7. Write a Pandas program to create a histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-04-18")]
plt.hist(fdf['Open'], bins=10, alpha=0.5, label='Open', color='r' )
plt.hist(fdf['Close'], bins=10, alpha=0.5, label='Close', color='b')
plt.hist(fdf['High'], bins=10, alpha=0.5, label='High', color='g')
plt.hist(fdf['Low'], bins=10, alpha=0.5, label='Low', color='y')

plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Alphabet Inc. Stock Prices (2020)')
plt.legend()
plt.show()

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Open','Close','High','Low']]
plt.figure(figsize=(25,25))
df2.plot.hist(alpha=0.5)
plt.show()

# %% [markdown]
# 8. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Open','Close','High','Low']]
plt.figure(figsize=(25,25))
df2.plot.hist(alpha=0.5, stacked=True)
plt.show()

# %% [markdown]
# 9. Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Open','Close','High','Low']]
plt.figure(figsize=(25,25))
df2.plot.hist(alpha=0.5,  orientation='horizontal')
plt.show()

# %% [markdown]
# 10. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates with more bins.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Open','Close','High','Low']]
plt.figure(figsize=(25,25))
df2.plot.hist(alpha=0.5, stacked=True, orientation='horizontal')
plt.show()

# %% [markdown]
# 11. Write a Pandas program to create a stacked histograms plot with more bins of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Open','Close','High','Low']]
plt.figure(figsize=(25,25))
df2.plot.hist(alpha=0.5, bins=50)
plt.show()

# %% [markdown]
# 12. Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Date','Close','Volume']]
df2.set_index(['Date'], inplace=True)
top_plt = plt.subplot2grid((5,4), (0, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["Close"])
plt.title('Historical stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
bottom_plt = plt.subplot2grid((5,4), (3,0), rowspan=1, colspan=4)
bottom_plt.bar(df2.index, df2['Volume'])
plt.title('\nAlphabet Inc. Trading Volume', y=-0.60)
plt.gcf().set_size_inches(12,8)

# %% [markdown]
# 13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Date','Open','High','Low','Close','Adj Close','Volume']]
df2.set_index(['Date'], inplace=True)

top_plt = plt.subplot2grid((20,4), (0, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["Open"])
plt.title('Open stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
top_plt = plt.subplot2grid((20,4), (3, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["High"])
plt.title('High stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
top_plt = plt.subplot2grid((20,4), (6, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["Low"])
plt.title('Low stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
top_plt = plt.subplot2grid((20,4), (9, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["Close"])
plt.title('Close stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
top_plt = plt.subplot2grid((20,4), (12, 0), rowspan=3, colspan=4)
top_plt.plot(df2.index, df2["Adj Close"])
plt.title('Adj Close stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
bottom_plt = plt.subplot2grid((20,4), (15,0), rowspan=1, colspan=4)
bottom_plt.bar(df2.index, df2['Volume'])
plt.title('\nAlphabet Inc. Trading Volume', y=-0.60)
plt.gcf().set_size_inches(12,8)

# %%
# @title{vertical-output:true}
plt.figure()
df2 = df[df["Date"].between("2020-04-06", "2020-04-18")][['Date','Open','High','Low','Close','Adj Close','Volume']]
df2.set_index(['Date'], inplace=True)

top_plt = plt.subplot2grid((20,4), (0, 0), rowspan=15, colspan=4)
top_plt.plot(df2['Open'], label='Open')
top_plt.plot(df2['High'], label='High')
top_plt.plot(df2['Low'], label='Low')
top_plt.plot(df2['Close'], label='Close')
plt.title('Stock prices of Alphabet Inc. [2020-04-06, 2020-04-18]')
plt.legend(loc='best')

bottom_plt = plt.subplot2grid((20,4), (17,0), rowspan=3, colspan=4)
bottom_plt.bar(df2.index, df2['Volume'])
plt.title('Alphabet Inc. Trading Volume', y=-0.60)

plt.gcf().set_size_inches(12, 8)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-cc28ff43fe2b>:19: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# 14. Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days simple moving average of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
# Extract and isolate 'Close' column, converting to DataFrame
df1 = df['Close'].to_frame()

# Calculate Cumulative Moving Average (CMA) with a window of 30
df1['CMA30'] = df1['Close'].expanding(30).mean()


# Print DataFrame
df1.plot()
plt.show()

# %% [markdown]
# 15. Write a Pandas program to create a plot of adjusted closing prices, 30 days simple moving average and exponential moving average of Alphabet Inc. between two specific dates.

# %%
# @title{vertical-output:true}
# Extract and isolate 'Close' column, converting to DataFrame
df1 = df['Close'].to_frame()

# Calculate Cumulative Moving Average (CMA) with a window of 30
df1['CMA30'] = df1['Close'].expanding(30).mean()

# Calculate Exponential Moving Average (EWMA) with a span of 30
df1['EWMA30'] = df1['Close'].ewm(span=30).mean()

# Print DataFrame
df1.plot()
plt.show()

# %%
df1.head()
# Out:
#          Close  CMA30       EWMA30
# 0  1105.619995    NaN  1105.619995
# 1  1120.839966    NaN  1113.483647
# 2  1097.880005    NaN  1107.931962
# 3  1186.920044    NaN  1129.696057
# 4  1186.510010    NaN  1142.622607

# %% [markdown]
# 16. Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. stock between two specific dates.

# %%
# @title{vertical-output:true}
plt.figure()
fdf=df[df["Date"].between("2020-04-06", "2020-09-18")]
plt.scatter(fdf['Volume'],fdf['Close'])
plt.xlabel('Trading Volume')
plt.ylabel('Closing Price')
plt.title('Alphabet Inc. Stock Price vs Trading Volume (2020)')
plt.grid(True)
plt.show()

# %%
# @title{vertical-output:true}

start_date = '2020-04-06'
end_date = '2020-05-18'

filtered_df = df[df['Date'].between(start_date, end_date)]

plt.figure(figsize=(10, 6))

plt.scatter(filtered_df['Date'], filtered_df['Volume'], alpha=0.5)
plt.scatter(filtered_df['Date'], filtered_df['Close'], alpha=0.5)

plt.title('Alphabet Inc. Stock: Trading Volume vs. Stock Price')
plt.xlabel('Stock Price (Close)')
plt.ylabel('Trading Volume')
plt.grid(True)
plt.show()

# %% [markdown]
# 17. Write a Pandas program to create a plot to visualize daily percentage returns of Alphabet Inc. stock price between two specific dates.

# %%
# @title{vertical-output:true}

start_date = '2020-04-06'
end_date = '2020-05-18'

filtered_df = df[df['Date'].between(start_date, end_date)]

plt.figure(figsize=(10, 6))

filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()

plt.plot(filtered_df['Date'], filtered_df['Daily_Return'])

plt.title('Alphabet Inc. Stock: Daily Percentage Returns')
plt.xlabel('Date')
plt.ylabel('Daily Percentage Return')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-29-4ce72dda1811>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()

# %% [markdown]
# 18. Write a Pandas program to plot the volatility over a period of time of Alphabet Inc. stock price between two specific dates.

# %%
# @title{vertical-output:true}

start_date = '2020-04-06'
end_date = '2020-05-18'

filtered_df = df[df['Date'].between(start_date, end_date)]

plt.figure(figsize=(10, 6))

filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()
filtered_df['Daily_Return_Squared'] = filtered_df['Daily_Return'] ** 2

plt.plot(filtered_df['Date'], filtered_df['Daily_Return_Squared'])

plt.title('Alphabet Inc. Stock: Volatility Over Time')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-31-53bc75010e10>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()
# <ipython-input-31-53bc75010e10>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily_Return_Squared'] = filtered_df['Daily_Return'] ** 2

# %% [markdown]
# 19. Write a Pandas program to create a histogram to visualize daily return distribution of Alphabet Inc. stock price between two specific dates.

# %%
# @title{vertical-output:true}

start_date = '2020-04-06'
end_date = '2020-05-18'

filtered_df = df[df['Date'].between(start_date, end_date)]

plt.figure(figsize=(10, 6))
filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()
plt.hist(filtered_df['Daily_Return'], bins=50, edgecolor='k')

plt.title('Alphabet Inc. Stock: Daily Return Distribution')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.grid(True)
# Out:
# <ipython-input-32-1b62f1d956cd>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Daily_Return'] = filtered_df['Close'].pct_change()
