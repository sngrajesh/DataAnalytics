# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title.
# ![Screenshot 2024-10-15 095307.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.arange(0,90,10)
y = np.arange(0,180,20)

plt.figure()
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# ---
#
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis, y axis and a title.
#    ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = [1,2,3]
y = [2,4,1]
plt.plot(x, y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Sample graph!')
plt.show()

# %% [markdown]
# ---
#
# 3. Write a Python program to draw a line using given axis values taken from a text file, with suitable label in the x axis, y axis and a title.
#
# **Test Data:**
#
# | test.txt |
# |----------|
# | 1 2      |
# | 2 4      |
# | 3 1      |
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
filepath = '/content/drive/MyDrive/Colab Notebooks/Data Sets/test.txt'
file_data = np.loadtxt(filepath, dtype=int).transpose()
print("File Data:\n", file_data, "\n")

plt.figure(figsize=(10,5))
plt.plot(file_data[0],file_data[1])
plt.xlabel('x -axis')
plt.ylabel('y -axis')
plt.title('Sample graph!')
plt.show()
# Out:
# File Data:
#  [[1 2 3]
#  [2 4 1]]

# %% [markdown]
# ---
#
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
#
# **Sample Financial data (fdata.csv):**
#
# | Date      | Open       | High       | Low        | Close       |
# |-----------|------------|------------|------------|-------------|
# | 10-03-16  | 774.25     | 776.065002 | 769.5      | 772.559998  |
# | 10-04-16  | 776.030029 | 778.710022 | 772.890015 | 776.429993  |
# | 10-05-16  | 779.309998 | 782.070007 | 775.650024 | 776.469971  |
# | 10-06-16  | 779        | 780.47998  | 775.539978 | 776.859985  |
# | 10-07-16  | 779.659973 | 779.659973 | 770.75     | 775.080017  |
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
filepath = '/content/drive/MyDrive/Colab Notebooks/Data Sets/fdata.csv'
df = pd.read_csv(filepath)

plt.figure()
df.plot.line()
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('F-Data')
plt.show()

# %% [markdown]
# ---
#
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line.
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.array([10, 15, 20, 25, 30])
y1 = np.array([20, 30, 40, 20, 0])
y2 = np.array([40, 20, 0, 20, 30])

plt.figure()

plt.plot(x, y1, label = "Line 1")
plt.plot(x, y2, label = "Line 2")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Two or more lines on same plot with suitable legends")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.array([10, 15, 20, 25, 30])
y1 = np.array([20, 30, 40, 20, 0])
y2 = np.array([40, 20, 0, 20, 30])

plt.figure()

plt.plot(x, y1, linewidth=1, label = "Line 1")
plt.plot(x, y2, linewidth=3, label = "Line 2")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Two or more lines on same plot with suitable legends")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# 7. Write a Python program to plot two or more lines with different styles.
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.array([10, 15, 20, 25, 30])
y1 = np.array([20, 30, 40, 20, 0])
y2 = np.array([40, 20, 0, 20, 30])

plt.figure()

plt.plot(x, y1, linestyle='dotted', label = "Line 1")
plt.plot(x, y2, linestyle='dashed', label = "Line 2")

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Two or more lines on same plot with suitable legends")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# 8. Write a Python program to plot two or more lines and set the line markers.
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.array([10, 15, 20, 25, 30])
y1 = np.array([20, 30, 40, 20, 0])
y2 = np.array([40, 20, 0, 20, 30])

plt.figure()

plt.plot(x, y2, linestyle='dashed', label = "Line 2", marker='o')
plt.plot(x, y1, linestyle='dotted', label = "Line 1", marker='*')

plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Two or more lines on same plot with suitable legends")
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# 9. Write a Python program to display the current axis limits values and set new axis values.
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)

x_lim = plt.xlim()
y_lim = plt.ylim()

print("Current x-axis limits:", x_lim)
print("Current y-axis limits:", y_lim)

plt.xlim(2, 8)
plt.ylim(-1.5, 1.5)

plt.show()
# Out:
# Current x-axis limits: (-0.5, 10.5)
# Current y-axis limits: (-1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# ---
#
# 10. Write a Python program to plot quantities which have an x and y position.
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
x1 = [2, 3, 5, 6, 8]
y1 = [1, 5, 10, 18, 20]
x2 = [3, 4, 6, 7, 9]
y2 = [2, 6, 11, 20, 22]
plt.axis([0, 10, 0, 30])
plt.plot(x1, y1,'b*')
plt.plot(x2, y2, 'ro')
plt.show()

# %% [markdown]
# ---
#
# 11. Write a Python program to plot several lines with different format styles in one command using arrays.
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
a = np.linspace(1,5,20)
b = a ** 2
c = a ** 3

plt.plot(a, b, '*')
plt.plot(a, c, '.')

# %% [markdown]
# ---
#
# 12. Write a Python program to create multiple types of charts (a simple curve and plot some quantities) on a single set of axes.
#
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# array([[705, 709],
#        [705, 709]])

# %%
#@title {vertical-output: true}
a = np.random.rand(5) + 700
dates = pd.date_range("2016-10-03", periods=len(a))
plt.figure()
plt.plot(dates, a)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ---
#
# 13. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with linestyle `-`, width `.5`, and color blue.
#
# **Sample Data:**
#
# | Date      | Close       |
# |-----------|-------------|
# | 03-10-16  | 772.559998  |
# | 04-10-16  | 776.429993  |
# | 05-10-16  | 776.469971  |
# | 06-10-16  | 776.859985  |
# | 07-10-16  | 775.080017  |
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
a = np.random.rand(5) + 700
dates = pd.date_range("2016-10-03", periods=len(a))
plt.figure()
plt.plot(dates, a)
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# 14. Write a Python program to display the grid and draw line charts of the closing value of Alphabet Inc. between October 3, 2016 to October 7, 2016. Customize the grid lines with rendering a larger grid (major grid) and a smaller grid (minor grid). Turn on the grid but turn off ticks.
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}
a = np.random.rand(5) + 700
dates = pd.date_range("2016-10-03", periods=len(a))
plt.figure()
plt.plot(dates, a)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing stock value of Alphabet Inc.')
plt.minorticks_on()

# Customize the major grid
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# Turn off the display of all ticks.
plt.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks
plt.show()

# %% [markdown]
# ---
#
# 15. Write a Python program to create multiple plots.
#
#
# ![image.png](data:image/png;base64,...)

# %%
#@title { vertical-output: true}

plot1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
plot2 = plt.subplot2grid((3, 3), (1, 0), rowspan=1, colspan=1)
plot3 = plt.subplot2grid((3, 3), (1, 1), rowspan=1, colspan=1)
plot4 = plt.subplot2grid((3, 3), (1, 2), rowspan=1, colspan=1)

x = np.arange(1, 10)

plot2.plot(x, x**0.5)
plot2.set_title('Square Root')

plot1.plot(x, np.exp(x))
plot1.set_title('Exponent')

plot3.plot(x, x*x)
plot3.set_title('Square')

plot4.plot(x, x*2)
plot4.set_title('Linear')

plt.tight_layout()
plt.show()
