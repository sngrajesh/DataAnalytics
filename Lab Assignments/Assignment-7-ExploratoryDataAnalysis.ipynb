# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Pandas program to detect missing values of a given DataFrame. Display True or False.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.isnull()
# Out:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# 1     True      False     False        False        False
# 2    False      False      True        False        False
# 3    False      False     False        False         True
# 4     True      False     False        False        False
# 5    False      False     False        False        False
# 6     True      False     False        False        False
# 7    False      False     False        False         True
# 8    False      False     False        False        False
# 9    False      False     False        False        False
# 10    True      False     False        False        False
# 11   False      False     False        False         True

# %% [markdown]
# 2. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

print(df.columns[df.isnull().any()].tolist())
# Out:
# ['ord_no', 'ord_date', 'salesman_id']

# %% [markdown]
# 3. Write a Pandas program to count the number of missing values in each column of a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.isnull().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %% [markdown]
# 4. Write a Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information.
#
# Test Data:
#
# ```
#    ord_no purch_amt    ord_date customer_id salesman_id
# 0   70001     150.5           ?        3002        5002
# 1     NaN    270.65  2012-09-10        3001        5003
# 2   70002     65.26         NaN        3001           ?
# 3   70004     110.5  2012-08-17        3003        5001
# 4     NaN     948.5  2012-09-10        3002         NaN
# 5   70005    2400.6  2012-07-27        3001        5002
# 6      --      5760  2012-09-10        3001        5001
# 7   70010         ?  2012-10-10        3004           ?
# 8   70003     12.43  2012-10-10          --        5003
# 9   70012    2480.4  2012-06-27        3002        5002
# 10    NaN    250.45  2012-08-17        3001        5003
# 11  70013    3045.6  2012-04-25        3001          --
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.fillna(df.mean())
# Out:
#       ord_no  purch_amt                      ord_date  customer_id  \
# 0   70001.00     150.50 2012-10-05 00:00:00.000000000         3002
# 1   70006.25     270.65 2012-09-10 00:00:00.000000000         3001
# 2   70002.00      65.26 2012-08-20 21:49:05.454545408         3001
# 3   70004.00     110.50 2012-08-17 00:00:00.000000000         3003
# 4   70006.25     948.50 2012-09-10 00:00:00.000000000         3002
# 5   70005.00    2400.60 2012-07-27 00:00:00.000000000         3001
# 6   70006.25    5760.00 2012-09-10 00:00:00.000000000         3001
# 7   70010.00    1983.43 2012-10-10 00:00:00.000000000         3004
# 8   70003.00    2480.40 2012-10-10 00:00:00.000000000         3003
# 9   70012.00     250.45 2012-06-27 00:00:00.000000000         3002
# 10  70006.25      75.29 2012-08-17 00:00:00.000000000         3001
# 11  70013.00    3045.60 2012-04-25 00:00:00.000000000         3001
#
#     salesman_id
# 0        5002.0
# 1        5003.0
# 2        5001.0
# 3        5002.0
# 4        5002.0
# 5        5001.0
# 6        5001.0
# 7        5002.0
# 8        5003.0
# 9        5002.0
# 10       5003.0
# 11       5002.0

# %% [markdown]
# 5. Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(how='any', axis=0)
# Out:
#     ord_no  purch_amt   ord_date  customer_id  salesman_id
# 0  70001.0     150.50 2012-10-05         3002       5002.0
# 5  70005.0    2400.60 2012-07-27         3001       5001.0
# 8  70003.0    2480.40 2012-10-10         3003       5003.0
# 9  70012.0     250.45 2012-06-27         3002       5002.0

# %% [markdown]
# 6. Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(how='any', axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %% [markdown]
# 7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, 270.65, 65.26, 110.50, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, 3045.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(how='all', axis=0)
# Out:
#      ord_no  purch_amt   ord_date  customer_id  salesman_id
# 0   70001.0     150.50 2012-10-05         3002       5002.0
# 1       NaN     270.65 2012-09-10         3001       5003.0
# 2   70002.0      65.26        NaT         3001       5001.0
# 3   70004.0     110.50 2012-08-17         3003          NaN
# 4       NaN     948.50 2012-09-10         3002       5002.0
# 5   70005.0    2400.60 2012-07-27         3001       5001.0
# 6       NaN    5760.00 2012-09-10         3001       5001.0
# 7   70010.0    1983.43 2012-10-10         3004          NaN
# 8   70003.0    2480.40 2012-10-10         3003       5003.0
# 9   70012.0     250.45 2012-06-27         3002       5002.0
# 10      NaN      75.29 2012-08-17         3001       5003.0
# 11  70013.0    3045.60 2012-04-25         3001          NaN

# %% [markdown]
# 8. Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
# ```

# %%
# @title{vertical-output:true}
data = {
    "ord_no": [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    "purch_amt": [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    "ord_date": [np.nan, "2012-09-10", np.nan, np.nan, "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", np.nan],
    "customer_id": [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
}
df = pd.DataFrame(data)
print(df,'\n')
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(thresh=2, inplace=True)
print(df)
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
#
#      ord_no  purch_amt   ord_date  customer_id
# 1       NaN     270.65 2012-09-10       3001.0
# 2   70002.0      65.26        NaT       3001.0
# 4       NaN     948.50 2012-09-10       3002.0
# 5   70005.0    2400.60 2012-07-27       3001.0
# 6       NaN    5760.00 2012-09-10       3001.0
# 7   70010.0    1983.43 2012-10-10       3004.0
# 8   70003.0    2480.40 2012-10-10       3003.0
# 9   70012.0     250.45 2012-06-27       3002.0
# 10      NaN      75.29 2012-08-17       3001.0

# %% [markdown]
# 9. Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values.
#
# Test Data:
#
# ```
#     ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
# ```

# %%
# @title{vertical-output:true}
data = {
    "ord_no": [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    "purch_amt": [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    "ord_date": [np.nan, "2012-09-10", np.nan, np.nan, "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", np.nan],
    "customer_id": [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(subset=['ord_date', 'customer_id'])
# Out:
#      ord_no  purch_amt   ord_date  customer_id
# 1       NaN     270.65 2012-09-10       3001.0
# 4       NaN     948.50 2012-09-10       3002.0
# 5   70005.0    2400.60 2012-07-27       3001.0
# 6       NaN    5760.00 2012-09-10       3001.0
# 7   70010.0    1983.43 2012-10-10       3004.0
# 8   70003.0    2480.40 2012-10-10       3003.0
# 9   70012.0     250.45 2012-06-27       3002.0
# 10      NaN      75.29 2012-08-17       3001.0

# %% [markdown]
# 10. Write a Pandas program to keep the valid entries of a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
# ```

# %%
data = [[np.nan, 270.65, '2012-09-10', 3001.0],
        [np.nan, 948.50, '2012-09-10', 3002.0],
        [70002.0, 65.26, np.nan, 3001.0],
        [np.nan, np.nan, np.nan, np.nan],
        [np.nan, 2400.60, '2012-07-27', 3001.0],
        [np.nan, 5760.00, '2012-09-10', 3001.0],
        [70010.0, 1983.43, '2012-10-10', 3004.0],
        [70003.0, 2480.40, '2012-10-10', 3003.0],
        [70012.0, 250.45, '2012-06-27', 3002.0],
        [np.nan, 75.29, '2012-08-17', 3001.0],
        [np.nan, np.nan, np.nan, np.nan]]

df = pd.DataFrame(data, columns=['ord_no', 'purch_amt', 'ord_date', 'customer_id'])
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.dropna(how='all')
# Out:
#     ord_no  purch_amt   ord_date  customer_id
# 0      NaN     270.65 2012-09-10       3001.0
# 1      NaN     948.50 2012-09-10       3002.0
# 2  70002.0      65.26        NaT       3001.0
# 4      NaN    2400.60 2012-07-27       3001.0
# 5      NaN    5760.00 2012-09-10       3001.0
# 6  70010.0    1983.43 2012-10-10       3004.0
# 7  70003.0    2480.40 2012-10-10       3003.0
# 8  70012.0     250.45 2012-06-27       3002.0
# 9      NaN      75.29 2012-08-17       3001.0

# %% [markdown]
# 11. Write a Pandas program to calculate the total number of missing values in a DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
# ```

# %%
data = {
    'ord_no': [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    'purch_amt': [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    'ord_date': [np.nan, '2012-09-10', np.nan, np.nan, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', np.nan],
    'customer_id': [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
}

df = pd.DataFrame(data)

df.isna().sum().sum()
# Out:
# 17

# %% [markdown]
# 12. Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt    ord_date  customer_id
# 0       NaN        NaN         NaN          NaN
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3       NaN        NaN         NaN          NaN
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11      NaN        NaN         NaN          NaN
# ```

# %%
data = {
    'ord_no': [np.nan, np.nan, 70002.0, np.nan, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, np.nan],
    'purch_amt': [np.nan, 270.65, 65.26, np.nan, 948.50, 2400.60, 5760.00, 1983.43, 2480.40, 250.45, 75.29, np.nan],
    'ord_date': [np.nan, '2012-09-10', np.nan, np.nan, '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', np.nan],
    'customer_id': [np.nan, 3001.0, 3001.0, np.nan, 3002.0, 3001.0, 3001.0, 3004.0, 3003.0, 3002.0, 3001.0, np.nan]
}

df = pd.DataFrame(data)

df.fillna({
    'ord_no': 0,
    'purch_amt': 0,
    'ord_date': '2012-01-01',
    'customer_id': 0
})
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 0       0.0       0.00  2012-01-01          0.0
# 1       0.0     270.65  2012-09-10       3001.0
# 2   70002.0      65.26  2012-01-01       3001.0
# 3       0.0       0.00  2012-01-01          0.0
# 4       0.0     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       0.0    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      0.0      75.29  2012-08-17       3001.0
# 11      0.0       0.00  2012-01-01          0.0

# %% [markdown]
# 13. Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ```

# %%
df = pd.DataFrame(data = {
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00],
    'sale_amt': [10.50, 20.65, np.nan, 11.50, 98.50, np.nan, 57.00],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0]
})

df.bfill()
# Out:
#     ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1  70002.0      65.26     20.65  2012-09-10         3001       5003.0
# 2  70002.0      65.26     11.50  2012-08-17         3001       5001.0
# 3  70004.0     110.50     11.50  2012-08-17         3003       5002.0
# 4  70005.0     948.50     98.50  2012-09-10         3002       5002.0
# 5  70005.0    5760.00     57.00  2012-07-27         3001       5001.0
# 6      NaN    5760.00     57.00  2012-09-10         3001       5001.0

# %% [markdown]
# 14. Write a Pandas program to replace NaNs with the median or mean of the specified columns in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    'sale_amt': [10.50, 20.65, np.nan, 11.50, 98.50, np.nan, 57.00, 19.43, np.nan, 25.45, 75.29, 35.60],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}

# Create a pandas DataFrame
df = pd.DataFrame(data)

df.fillna({
    'purch_amt': df['purch_amt'].mean(),
    'sale_amt': df['sale_amt'].median()
})
# Out:
#      ord_no    purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0   150.500000     10.50  2012-10-05         3002       5002.0
# 1       NaN  1376.614444     20.65  2012-09-10         3001       5003.0
# 2   70002.0    65.260000     25.45         NaN         3001       5001.0
# 3   70004.0   110.500000     11.50  2012-08-17         3003          NaN
# 4       NaN   948.500000     98.50  2012-09-10         3002       5002.0
# 5   70005.0  1376.614444     25.45  2012-07-27         3001       5001.0
# 6       NaN  5760.000000     57.00  2012-09-10         3001       5001.0
# 7   70010.0  1983.430000     19.43  2012-10-10         3004          NaN
# 8   70003.0  1376.614444     25.45  2012-10-10         3003       5003.0
# 9   70012.0   250.450000     25.45  2012-06-27         3002       5002.0
# 10      NaN    75.290000     75.29  2012-08-17         3001       5003.0
# 11  70013.0  3045.600000     35.60  2012-04-25         3001          NaN

# %% [markdown]
# 15. Write a Pandas program to interpolate the missing values using the Linear Interpolation method in a given DataFrame.
#
# From Wikipedia, in mathematics, linear interpolation is a method of curve fitting using linear polynomials to construct new data points within the range of a discrete set of known data points.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ```

# %%
data = {
    'ord_no': [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan],
    'purch_amt': [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00],
    'sale_amt': [10.50, 20.65, np.nan, 11.50, 98.50, np.nan, 57.00],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001],
    'salesman_id': [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0]
}

df = pd.DataFrame(data)
df['ord_date'] = pd.to_datetime(df['ord_date'], errors='coerce')

df.interpolate(method='linear')
# Out:
#     ord_no  purch_amt  sale_amt   ord_date  customer_id  salesman_id
# 0  70001.0     150.50    10.500 2012-10-05         3002       5002.0
# 1  70001.5     107.88    20.650 2012-09-10         3001       5003.0
# 2  70002.0      65.26    16.075 2012-08-29         3001       5001.0
# 3  70004.0     110.50    11.500 2012-08-17         3003       5001.5
# 4  70004.5     948.50    98.500 2012-09-10         3002       5002.0
# 5  70005.0    3354.25    77.750 2012-07-27         3001       5001.0
# 6  70005.0    5760.00    57.000 2012-09-10         3001       5001.0

# %% [markdown]
# 16. Write a Pandas program to count the number of missing values of a specified column in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
# ```

# %%
import pandas as pd

data = {'ord_no': [70001.0, float('nan'), 70002.0, 70004.0, float('nan'), 70005.0, float('nan'), 70010.0, 70003.0, 70012.0, float('nan'), 70013.0],
        'purch_amt': [150.50, float('nan'), 65.26, 110.50, 948.50, float('nan'), 5760.00, 1983.43, float('nan'), 250.45, 75.29, 3045.60],
        'sale_amt': [10.50, 20.65, float('nan'), 11.50, 98.50, float('nan'), 57.00, 19.43, float('nan'), 25.45, 75.29, 35.60],
        'ord_date': ['2012-10-05', '2012-09-10', float('nan'), '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
        'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
        'salesman_id': [5002.0, 5003.0, 5001.0, float('nan'), 5002.0, 5001.0, 5001.0, float('nan'), 5003.0, 5002.0, 5003.0, float('nan')]}

df = pd.DataFrame(data)
col='purch_amt'
df[col].isna().sum()
# Out:
# 3

# %% [markdown]
# 17. Write a Pandas program to count the missing values in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002
#
#  5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001        5003.0
# 2   70002.0      65.26       NaN         NaN         3001        5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003           NaN
# 4       NaN     948.50     98.50  2012-09-10         3002        5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001        5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001        5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004           NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003        5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002        5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001        5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001           NaN
# ```

# %%
import pandas as pd

data = {'ord_no': [70001.0, float('nan'), 70002.0, 70004.0, float('nan'), 70005.0, float('nan'), 70010.0, 70003.0, 70012.0, float('nan'), 70013.0],
        'purch_amt': [150.50, float('nan'), 65.26, 110.50, 948.50, float('nan'), 5760.00, 1983.43, float('nan'), 250.45, 75.29, 3045.60],
        'sale_amt': [10.50, 20.65, float('nan'), 11.50, 98.50, float('nan'), 57.00, 19.43, float('nan'), 25.45, 75.29, 35.60],
        'ord_date': ['2012-10-05', '2012-09-10', float('nan'), '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
        'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
        'salesman_id': [5002.0, 5003.0, 5001.0, float('nan'), 5002.0, 5001.0, 5001.0, float('nan'), 5003.0, 5002.0, 5003.0, float('nan')]}

df = pd.DataFrame(data)
df.isna().sum().sum()
# Out:
# 14

# %% [markdown]
# 18. Write a Pandas program to find the Indexes of missing values in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002        5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001        5003.0
# 2   70002.0      65.26       NaN         NaN         3001        5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003           NaN
# 4       NaN     948.50     98.50  2012-09-10         3002        5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001        5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001        5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004           NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003        5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002        5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001        5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001           NaN
# ```

# %%
data = {'ord_no': [70001.0, float('nan'), 70002.0, 70004.0, float('nan'), 70005.0, float('nan'), 70010.0, 70003.0, 70012.0, float('nan'), 70013.0],
        'purch_amt': [150.50, float('nan'), 65.26, 110.50, 948.50, float('nan'), 5760.00, 1983.43, float('nan'), 250.45, 75.29, 3045.60],
        'sale_amt': [10.50, 20.65, float('nan'), 11.50, 98.50, float('nan'), 57.00, 19.43, float('nan'), 25.45, 75.29, 35.60],
        'ord_date': ['2012-10-05', '2012-09-10', float('nan'), '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
        'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
        'salesman_id': [5002.0, 5003.0, 5001.0, float('nan'), 5002.0, 5001.0, 5001.0, float('nan'), 5003.0, 5002.0, 5003.0, float('nan')]}

df = pd.DataFrame(data)

# Find the indexes of missing values
print(df[df.isnull().any(axis=1)].index.tolist())
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 11]

# %% [markdown]
# 19. Write a Pandas program to replace the missing values with the most frequent values present in each column of a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002        5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001        5003.0
# 2   70002.0      65.26       NaN         NaN         3001        5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003           NaN
# 4       NaN     948.50     98.50  2012-09-10         3002        5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001        5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001        5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004           NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003        5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002        5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001        5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001           NaN
# ```

# %%
import pandas as pd

data = {'ord_no': [70001.0, float('nan'), 70002.0, 70004.0, float('nan'), 70005.0, float('nan'), 70010.0, 70003.0, 70012.0, float('nan'), 70013.0],
        'purch_amt': [150.50, float('nan'), 65.26, 110.50, 948.50, float('nan'), 5760.00, 1983.43, float('nan'), 250.45, 75.29, 3045.60],
        'sale_amt': [10.50, 20.65, float('nan'), 11.50, 98.50, float('nan'), 57.00, 19.43, float('nan'), 25.45, 75.29, 35.60],
        'ord_date': ['2012-10-05', '2012-09-10', float('nan'), '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10', '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
        'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
        'salesman_id': [5002.0, 5003.0, 5001.0, float('nan'), 5002.0, 5001.0, 5001.0, float('nan'), 5003.0, 5002.0, 5003.0, float('nan')]}

df = pd.DataFrame(data)
df.fillna(df.mode().iloc[0])
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0      65.26     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     10.50  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0      65.26     10.50  2012-07-27         3001       5001.0
# 6   70001.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0      65.26     10.50  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5001.0

# %%
df1 = pd.DataFrame(
        {'ord_no': [1,2,2,3,1,1,1],
         'no': [2,2,3,2,1,2,2]}
        )

m = df1.mode()
m['no']
# Out:
# 0    2
# Name: no, dtype: int64

# %% [markdown]
# 20. Write a Pandas program to create a heatmap for more information about the distribution of missing values in a given DataFrame.
#
# Test Data:
#
# ```
#      ord_no  purch_amt  sale_amt    ord_date  customer_id salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002        5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001        5003.0
# 2   70002.0      65.26       NaN         NaN         3001        5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003           NaN
# 4       NaN     948.50     98.50  2012-09-10         3002        5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001        5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001        5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004           NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003        5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002        5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001        5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001           NaN
# ```

# %%
data = {
    "ord_no": [70001.0, np.nan, 70002.0, 70004.0, np.nan, 70005.0, np.nan, 70010.0, 70003.0, 70012.0, np.nan, 70013.0],
    "purch_amt": [150.50, np.nan, 65.26, 110.50, 948.50, np.nan, 5760.00, 1983.43, np.nan, 250.45, 75.29, 3045.60],
    "sale_amt": [10.50, 20.65, np.nan, 11.50, 98.50, np.nan, 57.00, 19.43, np.nan, 25.45, 75.29, 35.60],
    "ord_date": ["2012-10-05", "2012-09-10", np.nan, "2012-08-17", "2012-09-10", "2012-07-27", "2012-09-10", "2012-10-10", "2012-10-10", "2012-06-27", "2012-08-17", "2012-04-25"],
    "customer_id": [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    "salesman_id": [5002.0, 5003.0, 5001.0, np.nan, 5002.0, 5001.0, 5001.0, np.nan, 5003.0, 5002.0, 5003.0, np.nan]
}
df = pd.DataFrame(data)
print(df)
# Create a heatmap to visualize missing values
plt.figure(figsize=(8, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN
